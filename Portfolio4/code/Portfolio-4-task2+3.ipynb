# %%
# !pip install labelme2coco
# Out:
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.6-py3-none-any.whl.metadata (3.5 kB)
# Collecting sahi>=0.8.19 (from labelme2coco)
#   Downloading sahi-0.11.36-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from labelme2coco) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco) (0.27.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (8.3.0)
# Collecting fire (from sahi>=0.8.19->labelme2coco)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting opencv-python<=4.11.0.86 (from sahi>=0.8.19->labelme2coco)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (11.3.0)
# Collecting pybboxes==0.1.6 (from sahi>=0.8.19->labelme2coco)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (2.32.4)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (2.1.2)
# Collecting terminaltables (from sahi>=0.8.19->labelme2coco)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (2.8.0+cu126)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pybboxes==0.1.6->sahi>=0.8.19->labelme2coco) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6.0->labelme2coco) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco) (3.4.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->sahi>=0.8.19->labelme2coco) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.1->sahi>=0.8.19->labelme2coco) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->sahi>=0.8.19->labelme2coco) (3.0.3)
# Downloading labelme2coco-0.2.6-py3-none-any.whl (19 kB)
# Downloading sahi-0.11.36-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 6.8 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 14.8 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.0 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, pybboxes, opencv-python, fire, sahi, labelme2coco
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
# Successfully installed fire-0.7.1 labelme2coco-0.2.6 opencv-python-4.11.0.86 pybboxes-0.1.6 sahi-0.11.36 terminaltables-3.1.10

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.8.0+cu126
# 12.6
# True

# %%
import labelme2coco


labelme_train = "/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train"
json_train = "/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train_coco"

labelme_test = "/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test"
json_test = "/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test_coco"


def convert_json_to_coco(json_path, export_path):
    """
    Convert JSON annotations to COCO format.

    Args:
        json_path (str): Path to the input JSON file.
        export_path (str): Path to save the output COCO JSON file.
    """
    # Convert JSON to COCO format
    labelme2coco.convert(json_path, export_path)
    print(f"Converted {json_path} to COCO format and saved to {export_path}")

# Convert training annotations
convert_json_to_coco(labelme_train, json_train)
# Convert testing annotations
convert_json_to_coco(labelme_test, json_test)
# Out:
# There are 8 listed files in folder train.
# Converting labelme annotations to COCO format: 100%|██████████| 8/8 [00:04<00:00,  1.76it/s]
# Converted /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train to COCO format and saved to /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train_coco
# There are 2 listed files in folder test.
# Converting labelme annotations to COCO format: 100%|██████████| 2/2 [00:00<00:00,  2.02it/s]
# Converted /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test to COCO format and saved to /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test_coco

# %%
import os
import torch
import torchvision
import numpy as np
import cv2
from torch.utils.data import Dataset, DataLoader
import json
import torchvision.transforms as T


# SECTION 1: Data Loading

print("SECTION 1: Data Loading...")


train_json = os.path.join(json_train, "dataset.json")
train_images = labelme_train

test_json = os.path.join(json_test, "dataset.json")
test_images = labelme_test

print(f"Train JSON: {train_json}")
print(f"Train Images Dir: {train_images}")
print(f"Test JSON: {test_json}")
print(f"Test Images Dir: {test_images}")

# Custom Dataset for COCO Annotations
class LogsDataset(Dataset):
    def __init__(self, coco_json, images_dir, transforms=None):
        self.images_dir = images_dir
        self.transforms = transforms
        # Load COCO-like JSON
        with open(coco_json, 'r') as f:
            data = json.load(f)
        self.images = data['images']
        self.annotations = data['annotations']
        self.categories = data['categories']

        # Build index of image_id -> list of annotation indexes
        self.img_id_to_ann = {}
        for i, ann in enumerate(self.annotations):
            img_id = ann['image_id']
            if img_id not in self.img_id_to_ann:
                self.img_id_to_ann[img_id] = []
            self.img_id_to_ann[img_id].append(i)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_info = self.images[idx]
        img_id = img_info['id']
        file_name = img_info['file_name']
        img_path = os.path.join(self.images_dir, file_name)

        # Load image
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB

        # Gather annotations
        ann_ids = self.img_id_to_ann.get(img_id, [])
        boxes = []
        labels = []

        for ann_id in ann_ids:
            ann = self.annotations[ann_id]
            # Single class "log" => label=1
            labels.append(1)
            # Bbox in COCO is [x, y, width, height]
            x, y, w, h = ann['bbox']
            boxes.append([x, y, x + w, y + h])

        # Convert to torch tensors
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)

        masks = torch.zeros((len(boxes), img.shape[0], img.shape[1]), dtype=torch.uint8)

        target = {
            "boxes": boxes,
            "labels": labels,
            "masks": masks
        }

        if self.transforms:
            img = self.transforms(img)

        return img, target
# Out:
# SECTION 1: Data Loading...
# Train JSON: /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train_coco/dataset.json
# Train Images Dir: /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/train
# Test JSON: /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test_coco/dataset.json
# Test Images Dir: /content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/Data/task2/test

# %%
# Transforms
transform = T.Compose([
    T.ToTensor(),
])

# Create datasets
dataset_train = LogsDataset(train_json, train_images, transforms=transform)
dataset_test  = LogsDataset(test_json, test_images, transforms=transform)

print(f"Number of training images: {len(dataset_train)}")
print(f"Number of testing images: {len(dataset_test)}")

# Create dataloaders
def collate_fn(batch):
    return tuple(zip(*batch))

train_loader = DataLoader(
    dataset_train,
    batch_size=2,
    shuffle=True,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    dataset_test,
    batch_size=2,
    shuffle=False,
    collate_fn=collate_fn
)

print("Data Loading Complete.\n")
# Out:
# Number of training images: 8
# Number of testing images: 2
# Data Loading Complete.

# %%
# SECTION 2: Model Setup

print("SECTION 2: Model Setup...")

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f"Device being used: {device}")

# Load pre-trained PyTorch Mask R-CNN
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
print("Loaded pre-trained Mask R-CNN.")

# Replace classifier head (box predictor)
num_classes = 2  # 1 (log) + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(
    in_features, num_classes
)

# Replace mask predictor
in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256
model.roi_heads.mask_predictor = torchvision.models.detection.mask_rcnn.MaskRCNNPredictor(
    in_features_mask, hidden_layer, num_classes
)

model.to(device)
print("Model moved to device.")
print("Model Setup Complete.\n")
# Out:
# SECTION 2: Model Setup...
# Device being used: cuda
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 170M/170M [00:00<00:00, 182MB/s]
# Loaded pre-trained Mask R-CNN.
# Model moved to device.
# Model Setup Complete.

# %%
# SECTION 3: Training & Testing

print("SECTION 3: Training & Testing...")

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)

num_epochs = 10
print(f"Starting training for {num_epochs} epochs...")

model.train()
for epoch in range(num_epochs):
    print(f"Starting Epoch {epoch+1}...")
    total_loss = 0.0

    for step, (imgs, targets) in enumerate(train_loader):
        imgs = [img.to(device) for img in imgs]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, targets)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        total_loss += losses.item()
        if (step + 1) % 10 == 0:
            print(f"  [Step {step+1}] Loss: {losses.item():.4f}")

    avg_loss = total_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}] - Average Loss: {avg_loss:.4f}")

print("Training completed.\n")
# Out:
# SECTION 3: Training & Testing...
# Starting training for 10 epochs...
# Starting Epoch 1...
# Epoch [1/10] - Average Loss: 3.1797
# Starting Epoch 2...
# Epoch [2/10] - Average Loss: 0.9435
# Starting Epoch 3...
# Epoch [3/10] - Average Loss: 0.5655
# Starting Epoch 4...
# Epoch [4/10] - Average Loss: 0.4959
# Starting Epoch 5...
# Epoch [5/10] - Average Loss: 0.3825
# Starting Epoch 6...
# Epoch [6/10] - Average Loss: 0.3143
# Starting Epoch 7...
# Epoch [7/10] - Average Loss: 0.2566
# Starting Epoch 8...
# Epoch [8/10] - Average Loss: 0.2245
# Starting Epoch 9...
# Epoch [9/10] - Average Loss: 0.2113
# Starting Epoch 10...
# Epoch [10/10] - Average Loss: 0.1859
# Training completed.

# %%
print("Starting Evaluation / Testing")
model.eval()
log_counts = {}

with torch.no_grad():
    for i, (imgs, targets) in enumerate(test_loader):
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        for img_i, output in enumerate(outputs):
            boxes = output["boxes"].cpu().numpy()
            scores = output["scores"].cpu().numpy()
            threshold = 0.5
            keep = scores >= threshold
            count_logs = sum(keep)
            log_counts[f"batch{i}_img{img_i}"] = count_logs

print("Testing completed.")
print("Log Counts:", log_counts)

print("\nSECTION 3: Training & Testing Complete.")
# Out:
# Starting Evaluation / Testing
# Testing completed.
# Log Counts: {'batch0_img0': np.int64(9), 'batch0_img1': np.int64(10)}
#
# SECTION 3: Training & Testing Complete.

# %%
torch.save(model, '/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/models/maskrcnn_model_full.pth')
print("Entire model saved as 'maskrcnn_model_full.pth'")
# Out:
# Entire model saved as 'maskrcnn_model_full.pth'

# %%
import cv2
import numpy as np

def draw_predictions(image, boxes, scores, threshold=0.5):

    image = np.ascontiguousarray(image)
    for box, score in zip(boxes, scores):
        if score >= threshold:
            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, f"log: {score:.2f}", (x1, y1-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    return image


with torch.no_grad():
    for i, (imgs, targets) in enumerate(test_loader):
        imgs = list(img.to(device) for img in imgs)
        outputs = model(imgs)

        for img_i, output in enumerate(outputs):
            # Convert tensor image back to NumPy (after moving to CPU)
            np_img = imgs[img_i].permute(1, 2, 0).cpu().numpy()
            np_img = (np_img * 255).astype(np.uint8)

            boxes = output["boxes"].cpu().numpy()
            scores = output["scores"].cpu().numpy()


            # Draw predictions and capture the modified image
            np_img = draw_predictions(np_img, boxes, scores, threshold=0.5)

            # Save result; converting color from RGB to BGR for OpenCV
            cv2.imwrite(f"/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/rcnn_test/detected_batch{i}_img{img_i}.jpg", cv2.cvtColor(np_img, cv2.COLOR_RGB2BGR))

# %%
import cv2
import os

def count_logs_in_image(image_path):
    """
    Loads an image and counts the number of green bounding boxes (logs).
    """
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load image {image_path}")
        return 0

    # Convert the image to HSV color space to easily detect green
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    # Define the range for green color in HSV
    # These values might need adjustment based on the exact shade of green used
    lower_green = np.array([35, 100, 100])
    upper_green = np.array([85, 255, 255])

    # Create a mask for green pixels
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Find contours in the mask
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Count the number of contours (assuming each contour corresponds to a log bounding box)
    # We can add further checks here if needed, e.g., based on contour area
    log_count = len(contours)

    return log_count

# Directory containing the saved images
output_dir = "/content/drive/MyDrive/Colab Notebooks/AI for engineering/Portfolio 4/rcnn_test"

# Iterate through the images in the directory and count logs
for filename in os.listdir(output_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(output_dir, filename)
        count = count_logs_in_image(image_path)
        print(f"Image: {filename}, Detected Logs: {count}")
# Out:
# Image: detected_batch0_img0.jpg, Detected Logs: 11
# Image: detected_batch0_img1.jpg, Detected Logs: 23
